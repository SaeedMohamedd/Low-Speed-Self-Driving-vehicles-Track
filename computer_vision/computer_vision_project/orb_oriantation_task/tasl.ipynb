# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread('frame1.png',0)
# Initiate ORB detector
orb = cv.ORB_create()
# find the keypoints with ORB
kp = orb.detect(img,None)
# compute the descriptors with ORB
kp, des = orb.compute(img, kp)
# draw only keypoints location,not size and orientation
img2 = cv.drawKeypoints(img, kp, None, color=(0,255,0), flags=0)
plt.imshow(img2), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f926f8e8fd0>, None)

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread('frame2.png',0)
# Initiate ORB detector
orb = cv.ORB_create()
# find the keypoints with ORB
kp = orb.detect(img,None)
# compute the descriptors with ORB
kp, des = orb.compute(img, kp)
# draw only keypoints location,not size and orientation
img2 = cv.drawKeypoints(img, kp, None, color=(0,255,0), flags=0)
plt.imshow(img2), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f926d60c650>, None)

# %%
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline
import time

# read images
img1 = cv2.imread('frame1.png')  
img2 = cv2.imread('frame2.png')  

img2 = cv2.resize(img1, None, fx=0.5, fy=0.5)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

#sift
orb = cv2.ORB_create()
t0 = time.time()
keypoints_1, descriptors_1 = orb.detectAndCompute(img1, None)
keypoints_2, descriptors_2 = orb.detectAndCompute(img2, None)

#feature matching
bf = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)

matches = bf.match(descriptors_1, descriptors_2)

matches = sorted(matches, key = lambda x:x.distance)

print ("Execution time: " + str(time.time() - t0))

img3 = cv2.drawMatches(img1, keypoints_1, img2, keypoints_2, matches, img2, flags=2)
plt.figure(figsize=(25,15))
plt.imshow(img3)
plt.show()
# Out:
# Execution time: 0.15090274810791016

# %%
i=0
for k1 in keypoints_1:
    p=k1.pt
    print(p)
    i+=1
    if i==21:
        break
# Out:
# (163.0, 32.0)
# (116.0, 34.0)
# (213.0, 36.0)
# (211.0, 37.0)
# (119.0, 45.0)
# (118.0, 47.0)
# (117.0, 49.0)
# (125.0, 49.0)
# (113.0, 52.0)
# (115.0, 56.0)
# (115.0, 93.0)
# (122.0, 122.0)
# (125.0, 123.0)
# (110.0, 126.0)
# (173.0, 129.0)
# (167.0, 130.0)
# (116.0, 131.0)
# (188.0, 133.0)
# (116.0, 141.0)
# (58.0, 142.0)
# (48.0, 143.0)

# %%
i=0
for k1 in keypoints_2:
    p=k1.pt
    print(p)
    i+=1
    if i==21:
        break
# Out:
# (79.0, 36.0)
# (57.0, 46.0)
# (89.0, 62.0)
# (76.0, 63.0)
# (86.0, 64.0)
# (94.0, 66.0)
# (57.0, 70.0)
# (56.400001525878906, 45.60000228881836)
# (58.80000305175781, 62.400001525878906)
# (91.20000457763672, 62.400001525878906)
# (84.0, 63.60000228881836)
# (93.60000610351562, 66.0)
# (56.400001525878906, 69.60000610351562)
# (59.040000915527344, 61.92000198364258)
# (83.52000427246094, 63.36000061035156)
# (93.60000610351562, 64.80000305175781)
# (56.160003662109375, 69.12000274658203)
# (60.48000717163086, 62.2080078125)
# (89.85601043701172, 62.2080078125)
# (84.67200469970703, 63.936004638671875)

# %%
type(keypoints_1)
# Out:
# list

# %%
for i in keypoints_1
# Out:
# <KeyPoint 0x7f926ee49ea0>

# %%
import math
i=0
d_x=[]
d_y=[]
t_x=0
t_y=0
while i !=20 :
    print(keypoints_2[i].pt[0]-keypoints_1[i].pt[0],keypoints_2[i].pt[1]-keypoints_1[i].pt[1],math.atan(keypoints_1[i].pt[0]-keypoints_2[i].pt[0]/keypoints_1[i].pt[1]-keypoints_2[i].pt[1]))
    d_x.append(keypoints_2[i].pt[0]-keypoints_1[i].pt[0])
    d_y.append(keypoints_2[i].pt[1]-keypoints_1[i].pt[1])
    t_x+=keypoints_2[i].pt[0]-keypoints_1[i].pt[0]
    t_y+=keypoints_2[i].pt[1]-keypoints_1[i].pt[1]
    i+=1
# Out:
# -84.0 4.0 1.5627663864659131
# -59.0 12.0 1.5561611255513774
# -124.0 26.0 1.5640636811887336
# -135.0 26.0 1.5639445821666498
# -33.0 19.0 1.5519622208840615
# -24.0 19.0 1.550798992821746
# -60.0 21.0 1.5489832243164374
# -68.5999984741211 -3.3999977111816406 1.5580173027132458
# -54.19999694824219 10.400001525878906 1.5505844932969242
# -23.79999542236328 6.400001525878906 1.5511800086020997
# -31.0 -29.39999771118164 1.55099566884818
# -28.399993896484375 -56.0 1.5526931164947924
# -68.5999984741211 -53.399993896484375 1.5525971445505242
# -50.959999084472656 -64.07999801635742 1.549796053044344
# -89.47999572753906 -65.63999938964844 1.5616216458390728
# -73.39999389648438 -65.19999694824219 1.5609424869814197
# -59.839996337890625 -61.87999725341797 1.5492717264477927
# -127.51999282836914 -70.7919921875 1.5628180223410146
# -26.14398956298828 -78.7919921875 1.5519855394751763
# 26.67200469970703 -78.06399536132812 -1.4188898989742056

# %%
print(t_x/20,t_y/20)
# Out:
# -59.71359729766846 -24.1423978805542

# %%
f_x=t_x/20
f_y=t_y/20
if f_x >0:
    print("right")
else:
    print("left")

if f_y >0:
    print("down")
else:
    print("Up")
# Out:
# left
# Up

# %%
import math
math.atan(0.64)

# %%
## Y result in negative this means fram2 going to y direction (up)
## x result is negative this meams fram2 going to x direction (left)
## O is too small mean that moving forward

# %%
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline
import time

# read images
img1 = cv2.imread('saved_img1.png')  
img2 = cv2.imread('saved_img2.png')  

img2 = cv2.resize(img1, None, fx=0.5, fy=0.5)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

#sift
orb = cv2.ORB_create()
t0 = time.time()
keypoints_1, descriptors_1 = orb.detectAndCompute(img1, None)
keypoints_2, descriptors_2 = orb.detectAndCompute(img2, None)

#feature matching
bf = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)

matches = bf.match(descriptors_1, descriptors_2)

matches = sorted(matches, key = lambda x:x.distance)

print ("Execution time: " + str(time.time() - t0))

img3 = cv2.drawMatches(img1, keypoints_1, img2, keypoints_2, matches, img2, flags=2)
plt.figure(figsize=(25,15))
plt.imshow(img3)
plt.show()


import math
i=0
d_x=[]
d_y=[]
t_x=0
t_y=0
a_x1=0
a_y1=0
a_x2=0
a_y2=0
len_k1=len(keypoints_1)-1
len_k2=len(keypoints_2)-1
if len_k1>len_k2:
    len_k1=len_k2
while i < len_k1:
    #print(keypoints_2[i].pt[0]-keypoints_1[i].pt[0],keypoints_2[i].pt[1]-keypoints_1[i].pt[1],math.atan(keypoints_1[i].pt[0]-keypoints_2[i].pt[0]/keypoints_1[i].pt[1]-keypoints_2[i].pt[1]))
    d_x.append(keypoints_2[i].pt[0]-keypoints_1[i].pt[0])
    d_y.append(keypoints_2[i].pt[1]-keypoints_1[i].pt[1])
    t_x+=keypoints_2[i].pt[0]-keypoints_1[i].pt[0]
    t_y+=keypoints_2[i].pt[1]-keypoints_1[i].pt[1]
    a_x1+=keypoints_1[i].pt[0]
    a_y1+=keypoints_1[i].pt[1]
    a_x2+=keypoints_2[i].pt[0]
    a_y2+=keypoints_2[i].pt[1]
    i+=1

f_x=t_x/20
f_y=t_y/20

print(a_x1/len_k1,a_y1/len_k1,a_x2/len_k1,a_y2/len_k1)
print(t_x/20,t_y/20)
if f_x >0:
    print("right")
else:
    print("left")

if f_y >0:
    print("down")
else:
    print("Up")
# Out:
# Execution time: 0.008077383041381836
# 138.86153969397913 99.27692354642429 83.52154056842511 61.21846257723295
# -71.94199886322022 -49.47599925994873
# left
# Up

# %%
x1=int(a_x1/len_k1)
y1=int(a_y1/len_k1)
x2=int(a_x2/len_k1)
y2=int(a_y2/len_k1)
i=img1.copy()
cv2.arrowedLine(i,(x1,y1),(x2,y2),(255,0,0),10);
plt.figure(figsize=(25,15))
plt.imshow(i)
plt.show()
