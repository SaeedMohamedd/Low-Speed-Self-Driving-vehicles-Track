# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('chess.png')
img_resize = cv2.resize(img, (500, 500))
plt.imshow(img_resize[:,:,::-1]);
gray = cv2.cvtColor(img_resize, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)

# %% [markdown]
# ## chess image

# %%
import numpy as np
import cv2
from datetime import datetime
import time

img_resize = cv2.imread('chess.png')
img = cv2.resize(img_resize, (500, 500))
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)

def nothing(x):
    pass

cv2.namedWindow('Harris', cv2.WINDOW_NORMAL)

cv2.createTrackbar('blocksize', 'Harris', 1, 20, nothing)
cv2.createTrackbar('apertureSize', 'Harris', 1, 20, nothing)
cv2.createTrackbar('k', 'Harris', 1, 20, nothing)


while 1:
    image= gray.copy()
    img2=img.copy()
    blockSize = cv2.getTrackbarPos('blocksize','Harris')
    apertureSize = cv2.getTrackbarPos('apertureSize','Harris')
    k = cv2.getTrackbarPos('k','Harris') /1000
    if apertureSize %2 == 0 :
        apertureSize+=1
    if blockSize == 0 :
        blockSize=1
    #dt1 = datetime.now()
    #dt1.microsecond
    start = time.time()
    dst = cv2.cornerHarris(image, blockSize, apertureSize, k)
    end = time.time()
    #dst = cv2.cornerHarris(gray, 2, 5, 0.07)
    #dt2 = datetime.now()
    #dt2.microsecond
    #print(d)
    print((end - start)*1000) # to convert to millisecond
    dst = cv2.dilate(dst, None)

    img2[dst > 0.01 * dst.max()] = [0, 0, 255]
    cv2.imshow('Harris', img2)

    k = cv2.waitKey(1)
    if k == 27:
        break
    if k == 115:
        cv2.imwrite("chess_edges.png", img2)

cv2.destroyAllWindows()
# Out:
# 859
# 5.714178085327148
# 6.103992462158203
# 5.613565444946289
# 5.128145217895508
# 5.530834197998047
# 5.749702453613281
# 5.959510803222656
# 6.093263626098633
# 6.356239318847656
# 6.352424621582031
# 7.407188415527344
# 6.272554397583008
# 5.572795867919922
# 6.16765022277832
# 6.263017654418945
# 6.958723068237305
# 5.841970443725586
# 5.62739372253418
# 5.748748779296875
# 5.393028259277344
# 6.517887115478516
# 6.878852844238281
# 7.007360458374023
# 19.364356994628906
# 9.804964065551758
# 6.884336471557617
# 5.833625793457031
# 7.303476333618164
# 6.362199783325195
# 5.485773086547852
# 5.894660949707031
# 5.153656005859375
# 5.556583404541016
# 5.778312683105469
# 7.863521575927734
# 5.769968032836914
# 5.590200424194336
# 7.193088531494141
# 6.104707717895508
# 6.6699981689453125
# 5.698680877685547
# 5.074739456176758
# 5.991458892822266
# 5.771160125732422
# 6.085634231567383
# 5.917549133300781
# 5.803585052490234
# 4.997014999389648
# 6.403207778930664
# ...

# %% [markdown]
# ## 001.png

# %%
import numpy as np
import cv2
import time

img_resize = cv2.imread('001.png')
img = cv2.resize(img_resize, (500, 500))
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)

def nothing(x):
    pass

cv2.namedWindow('Harris', cv2.WINDOW_NORMAL)

cv2.createTrackbar('blocksize', 'Harris', 1, 30, nothing)
cv2.createTrackbar('apertureSize', 'Harris', 1, 30, nothing)
cv2.createTrackbar('k', 'Harris', 1, 50, nothing)
cv2.createTrackbar('th', 'Harris', 1, 50, nothing)


while 1:
    image= gray.copy()
    img2=img.copy()
    blockSize = cv2.getTrackbarPos('blocksize','Harris')
    apertureSize = cv2.getTrackbarPos('apertureSize','Harris')
    k = cv2.getTrackbarPos('k','Harris') /100
    th=cv2.getTrackbarPos('th','Harris') /100
    if apertureSize %2 == 0 :
        apertureSize+=1
    if blockSize == 0 :
        blockSize=1

    start = time.time()
    dst = cv2.cornerHarris(image, blockSize, apertureSize, k)
    end = time.time()
    print((end - start)*1000) # to convert to millisecond
    #dst = cv2.cornerHarris(gray, 2, 5, 0.07)

    dst = cv2.dilate(dst, None)

    img2[dst > th * dst.max()] = [0, 0, 255]
    cv2.imshow('Harris', img2)

    k = cv2.waitKey(1)
    if k == 27:
        break
    if k == 115:
        cv2.imwrite("001_edges.png", img2)

cv2.destroyAllWindows()
# Out:
# 5.6285858154296875
# 6.287574768066406
# 5.506038665771484
# 7.665395736694336
# 4.819631576538086
# 5.9566497802734375
# 4.814863204956055
# 5.855560302734375
# 6.531953811645508
# 7.056713104248047
# 5.530357360839844
# 5.654335021972656
# 5.256414413452148
# 5.120515823364258
# 4.882335662841797
# 5.6362152099609375
# 5.607843399047852
# 5.649328231811523
# 5.138397216796875
# 5.680322647094727
# 5.378961563110352
# 5.887508392333984
# 8.574724197387695
# 8.670330047607422
# 4.960298538208008
# 6.623506546020508
# 6.523847579956055
# 5.706071853637695
# 5.948543548583984
# 6.389141082763672
# 4.812717437744141
# 5.301475524902344
# 5.318880081176758
# 6.5860748291015625
# 5.529642105102539
# 5.827665328979492
# 6.109952926635742
# 6.756305694580078
# 5.84721565246582
# 5.712032318115234
# 5.419015884399414
# 7.006645202636719
# 5.316972732543945
# 5.446434020996094
# 4.740238189697266
# 5.277395248413086
# 5.794048309326172
# 6.6986083984375
# 5.650043487548828
# ...

# %% [markdown]
# # 002.png

# %%
import numpy as np
import cv2
import time

img_resize = cv2.imread('002.png')
img = cv2.resize(img_resize, (500, 500))
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)

def nothing(x):
    pass

cv2.namedWindow('Harris', cv2.WINDOW_NORMAL)

cv2.createTrackbar('blocksize', 'Harris', 1, 30, nothing)
cv2.createTrackbar('apertureSize', 'Harris', 1, 30, nothing)
cv2.createTrackbar('k', 'Harris', 1, 50, nothing)
cv2.createTrackbar('th', 'Harris', 1, 50, nothing)


while 1:
    image= gray.copy()
    img2=img.copy()
    blockSize = cv2.getTrackbarPos('blocksize','Harris')
    apertureSize = cv2.getTrackbarPos('apertureSize','Harris')
    k = cv2.getTrackbarPos('k','Harris') /100
    th=cv2.getTrackbarPos('th','Harris') /100
    if apertureSize %2 == 0 :
        apertureSize+=1
    if blockSize == 0 :
        blockSize=1

    start = time.time()
    dst = cv2.cornerHarris(image, blockSize, apertureSize, k)
    end = time.time()
    print((end - start)*1000) # to convert to millisecond
    #dst = cv2.cornerHarris(gray, 2, 5, 0.07)

    dst = cv2.dilate(dst, None)

    img2[dst > th * dst.max()] = [0, 0, 255]
    cv2.imshow('Harris', img2)

    k = cv2.waitKey(1)
    if k == 27:
        break
    if k == 115:
        cv2.imwrite("002_edges.png", img2)

cv2.destroyAllWindows()
# Out:
# 814453
# 5.307912826538086
# 5.138635635375977
# 5.558252334594727
# 5.191564559936523
# 5.19561767578125
# 5.390405654907227
# 6.483316421508789
# 5.031108856201172
# 5.420923233032227
# 6.047725677490234
# 7.086038589477539
# 6.119012832641602
# 5.123376846313477
# 5.19251823425293
# 6.250143051147461
# 4.902362823486328
# 5.845308303833008
# 5.222320556640625
# 5.124330520629883
# 5.787134170532227
# 5.906343460083008
# 5.34510612487793
# 5.085229873657227
# 5.686521530151367
# 5.076885223388672
# 5.260229110717773
# 7.744550704956055
# 4.917621612548828
# 5.441188812255859
# 4.805803298950195
# 6.879091262817383
# 11.022806167602539
# 6.354808807373047
# 6.873130798339844
# 5.907535552978516
# 5.890130996704102
# 5.644321441650391
# 5.067110061645508
# 6.065845489501953
# 5.140781402587891
# 5.950927734375
# 5.328178405761719
# 5.978107452392578
# 5.367755889892578
# 5.467414855957031
# 5.523681640625
# 21.68130874633789
# 9.037256240844727
# 6.474733352661133
# ...

# %% [markdown]
# ## 003.png

# %%
import numpy as np
import cv2
import time

img_resize = cv2.imread('003.png')
img = cv2.resize(img_resize, (500, 500))
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)

def nothing(x):
    pass

cv2.namedWindow('Harris', cv2.WINDOW_NORMAL)

cv2.createTrackbar('blocksize', 'Harris', 1, 30, nothing)
cv2.createTrackbar('apertureSize', 'Harris', 1, 30, nothing)
cv2.createTrackbar('k', 'Harris', 1, 50, nothing)
cv2.createTrackbar('th', 'Harris', 1, 50, nothing)


while 1:
    image= gray.copy()
    img2=img.copy()
    blockSize = cv2.getTrackbarPos('blocksize','Harris')
    apertureSize = cv2.getTrackbarPos('apertureSize','Harris')
    k = cv2.getTrackbarPos('k','Harris') /100
    th=cv2.getTrackbarPos('th','Harris') /100
    if apertureSize %2 == 0 :
        apertureSize+=1
    if blockSize == 0 :
        blockSize=1

    start = time.time()
    dst = cv2.cornerHarris(image, blockSize, apertureSize, k)
    end = time.time()
    print((end - start)*1000) # to convert to millisecond
    #dst = cv2.cornerHarris(gray, 2, 5, 0.07)

    dst = cv2.dilate(dst, None)

    img2[dst > th * dst.max()] = [0, 0, 255]
    cv2.imshow('Harris', img2)

    k = cv2.waitKey(1)
    if k == 27:
        break
    if k == 115:
        cv2.imwrite("003_edges.png", img2)

cv2.destroyAllWindows()
# Out:
# 2.9807090759277344
# 4.8656463623046875
# 2.946138381958008
# 3.0782222747802734
# 3.2949447631835938
# 2.9633045196533203
# 4.148721694946289
# 4.314184188842773
# 2.9625892639160156
# 4.220724105834961
# 2.8867721557617188
# 3.839731216430664
# 3.1256675720214844
# 3.0226707458496094
# 3.3376216888427734
# 3.5066604614257812
# 3.2041072845458984
# 4.825353622436523
# 3.5140514373779297
# 2.8929710388183594
# 3.4456253051757812
# 2.9549598693847656
# 3.450155258178711
# 3.204345703125
# 3.151416778564453
# 4.385471343994141
# 3.2186508178710938
# 4.255771636962891
# 3.7457942962646484
# 3.0426979064941406
# 3.9649009704589844
# 3.397703170776367
# 3.016948699951172
# 3.9017200469970703
# 4.518747329711914
# 5.3730010986328125
# 3.6890506744384766
# 3.1037330627441406
# 11.589765548706055
# 10.205984115600586
# 7.44175910949707
# 4.712581634521484
# 3.795623779296875
# 5.789518356323242
# 4.987239837646484
# 4.3544769287109375
# 7.134914398193359
# 4.6939849853515625
# ...

# %% [markdown]
# ## 004.png

# %%
import numpy as np
import cv2
import time

img_resize = cv2.imread('004.png')
img = cv2.resize(img_resize, (500, 500))
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)

def nothing(x):
    pass

cv2.namedWindow('Harris', cv2.WINDOW_NORMAL)

cv2.createTrackbar('blocksize', 'Harris', 1, 30, nothing)
cv2.createTrackbar('apertureSize', 'Harris', 1, 30, nothing)
cv2.createTrackbar('k', 'Harris', 1, 50, nothing)
cv2.createTrackbar('th', 'Harris', 1, 50, nothing)


while 1:
    image= gray.copy()
    img2=img.copy()
    blockSize = cv2.getTrackbarPos('blocksize','Harris')
    apertureSize = cv2.getTrackbarPos('apertureSize','Harris')
    k = cv2.getTrackbarPos('k','Harris') /100
    th=cv2.getTrackbarPos('th','Harris') /100
    if apertureSize %2 == 0 :
        apertureSize+=1
    if blockSize == 0 :
        blockSize=1

    start = time.time()
    dst = cv2.cornerHarris(image, blockSize, apertureSize, k)
    end = time.time()
    print((end - start)*1000) # to convert to millisecond
    #dst = cv2.cornerHarris(gray, 2, 5, 0.07)

    dst = cv2.dilate(dst, None)

    img2[dst > th * dst.max()] = [0, 0, 255]
    cv2.imshow('Harris', img2)

    k = cv2.waitKey(1)
    if k == 27:
        break
    if k == 115:
        cv2.imwrite("004_edges.png", img2)

cv2.destroyAllWindows()
# Out:
# 669922
# 5.588054656982422
# 4.708051681518555
# 5.399465560913086
# 6.614446640014648
# 5.97834587097168
# 5.952358245849609
# 6.384134292602539
# 5.307912826538086
# 6.211519241333008
# 6.699323654174805
# 5.448818206787109
# 6.381034851074219
# 5.782127380371094
# 8.11314582824707
# 6.240367889404297
# 5.526304244995117
# 5.107641220092773
# 5.144596099853516
# 5.4473876953125
# 5.255699157714844
# 6.584644317626953
# 5.690097808837891
# 5.186557769775391
# 5.661725997924805
# 5.476474761962891
# 5.546331405639648
# 5.083322525024414
# 5.431413650512695
# 5.54656982421875
# 5.886316299438477
# 7.14874267578125
# 7.123708724975586
# 5.217790603637695
# 4.920244216918945
# 5.90062141418457
# 5.714893341064453
# 5.088329315185547
# 6.623268127441406
# 6.988048553466797
# 5.295515060424805
# 5.162715911865234
# 5.054712295532227
# 5.441904067993164
# 6.118297576904297
# 5.288839340209961
# 6.19196891784668
# 5.893468856811523
# 5.799770355224609
# 7.568597793579102
# ...

# %% [markdown]
# ## 005.png

# %%
import numpy as np
import cv2
import time

img_resize = cv2.imread('005.png')
img = cv2.resize(img_resize, (500, 500))
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)

def nothing(x):
    pass

cv2.namedWindow('Harris', cv2.WINDOW_NORMAL)

cv2.createTrackbar('blocksize', 'Harris', 1, 30, nothing)
cv2.createTrackbar('apertureSize', 'Harris', 1, 30, nothing)
cv2.createTrackbar('k', 'Harris', 1, 50, nothing)
cv2.createTrackbar('th', 'Harris', 1, 50, nothing)


while 1:
    image= gray.copy()
    img2=img.copy()
    blockSize = cv2.getTrackbarPos('blocksize','Harris')
    apertureSize = cv2.getTrackbarPos('apertureSize','Harris')
    k = cv2.getTrackbarPos('k','Harris') /100
    th=cv2.getTrackbarPos('th','Harris') /100
    if apertureSize %2 == 0 :
        apertureSize+=1
    if blockSize == 0 :
        blockSize=1

    start = time.time()
    dst = cv2.cornerHarris(image, blockSize, apertureSize, k)
    end = time.time()
    print((end - start)*1000) # to convert to millisecond
    #dst = cv2.cornerHarris(gray, 2, 5, 0.07)

    dst = cv2.dilate(dst, None)

    img2[dst > th * dst.max()] = [0, 0, 255]
    cv2.imshow('Harris', img2)

    k = cv2.waitKey(1)
    if k == 27:
        break
    if k == 115:
        cv2.imwrite("005_edges.png", img2)

cv2.destroyAllWindows()
# Out:
# 1192016602
# 6.012439727783203
# 8.338451385498047
# 5.984067916870117
# 6.101369857788086
# 6.081342697143555
# 6.103515625
# 6.498813629150391
# 6.496906280517578
# 7.648468017578125
# 6.567478179931641
# 5.581855773925781
# 8.203268051147461
# 4.810810089111328
# 8.336067199707031
# 5.846977233886719
# 6.721735000610352
# 5.15437126159668
# 5.742073059082031
# 6.8836212158203125
# 5.747318267822266
# 4.812955856323242
# 5.856037139892578
# 6.085872650146484
# 17.24410057067871
# 10.683059692382812
# 11.714458465576172
# 15.82479476928711
# 8.49461555480957
# 6.379842758178711
# 5.6896209716796875
# 5.370616912841797
# 5.4454803466796875
# 5.142450332641602
# 5.8803558349609375
# 5.804777145385742
# 5.366086959838867
# 4.913806915283203
# 5.222558975219727
# 5.034446716308594
# 5.31458854675293
# 4.686832427978516
# 6.1626434326171875
# 6.594181060791016
# 12.904882431030273
# 7.276773452758789
# 9.367704391479492
# 5.474567413330078
# 5.510807037353516
# 4.724264144897461
# ...

# %%
import numpy as np
import cv2
import time

img_resize = cv2.imread('006.png')
img = cv2.resize(img_resize, (500, 500))
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)

def nothing(x):
    pass

cv2.namedWindow('Harris', cv2.WINDOW_NORMAL)

cv2.createTrackbar('blocksize', 'Harris', 1, 30, nothing)
cv2.createTrackbar('apertureSize', 'Harris', 1, 30, nothing)
cv2.createTrackbar('k', 'Harris', 1, 50, nothing)
cv2.createTrackbar('th', 'Harris', 1, 50, nothing)


while 1:
    image= gray.copy()
    img2=img.copy()
    blockSize = cv2.getTrackbarPos('blocksize','Harris')
    apertureSize = cv2.getTrackbarPos('apertureSize','Harris')
    k = cv2.getTrackbarPos('k','Harris') /100
    th=cv2.getTrackbarPos('th','Harris') /100
    if apertureSize %2 == 0 :
        apertureSize+=1
    if blockSize == 0 :
        blockSize=1

    start = time.time()
    dst = cv2.cornerHarris(image, blockSize, apertureSize, k)
    end = time.time()
    print((end - start)*1000) # to convert to millisecond
    #dst = cv2.cornerHarris(gray, 2, 5, 0.07)

    dst = cv2.dilate(dst, None)

    img2[dst > th * dst.max()] = [0, 0, 255]
    cv2.imshow('Harris', img2)

    k = cv2.waitKey(1)
    if k == 27:
        break
    if k == 115:
        cv2.imwrite("006_edges.png", img2)

cv2.destroyAllWindows()
# Out:
# 5157470703125
# 6.650686264038086
# 6.33692741394043
# 5.329370498657227
# 5.10716438293457
# 5.681037902832031
# 5.621194839477539
# 5.321741104125977
# 5.231142044067383
# 5.311012268066406
# 5.803346633911133
# 5.385398864746094
# 4.988431930541992
# 6.842374801635742
# 6.428956985473633
# 6.370306015014648
# 5.003690719604492
# 6.26063346862793
# 6.736040115356445
# 6.473064422607422
# 4.996776580810547
# 5.272150039672852
# 6.100893020629883
# 6.44373893737793
# 5.155801773071289
# 5.305051803588867
# 5.6171417236328125
# 6.192684173583984
# 5.572319030761719
# 6.262540817260742
# 5.244255065917969
# 6.538629531860352
# 4.911661148071289
# 6.307363510131836
# 5.051612854003906
# 5.363941192626953
# 4.891872406005859
# 6.094455718994141
# 5.457878112792969
# 5.484819412231445
# 4.609346389770508
# 6.339550018310547
# 4.620075225830078
# 5.132198333740234
# 5.968809127807617
# 5.9757232666015625
# 7.629156112670898
# 7.275819778442383
# 6.055116653442383
# 6.117343902587891
# ...

# %% [markdown]
# ## the end

# %%
# organizing imports
import cv2
import numpy as np
  
# path to input image specified and 
# image is loaded with imread command
image = cv2.imread('chess.png')
img = cv2.resize(image, (500, 500)) 
# convert the input image into
# grayscale color space
operatedImage = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  
# modify the data type
# setting to 32-bit floating point
operatedImage = np.float32(operatedImage)
  
# apply the cv2.cornerHarris method
# to detect the corners with appropriate
# values as input parameters
dest = cv2.cornerHarris(operatedImage, 2, 5, 0.07)
  
# Results are marked through the dilated corners
dest = cv2.dilate(dest, None)
  
# Reverting back to the original image,
# with optimal threshold value
img[dest > 0.01 * dest.max()]=[0, 0, 255]
  
# the window showing output image with corners
cv2.imshow('Image with Borders', img)
  
# De-allocate any associated memory usage 
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()

# %%
# organizing imports
import cv2
import numpy as np
  
# path to input image specified and 
# image is loaded with imread command
image = cv2.imread('chess.png')
img = cv2.resize(image, (500, 500)) 
# convert the input image into
# grayscale color space
operatedImage = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  
# modify the data type
# setting to 32-bit floating point
operatedImage = np.float32(operatedImage)
  
# apply the cv2.cornerHarris method
# to detect the corners with appropriate
# values as input parameters
dest = cv2.cornerHarris(operatedImage, 2, 5, 0.07)
  
# Results are marked through the dilated corners
dest = cv2.dilate(dest, None)
  
# Reverting back to the original image,
# with optimal threshold value
img[dest > 0.01 * dest.max()]=[0, 0, 255]
  
# the window showing output image with corners
cv2.imshow('Image with Borders', img)
  
# De-allocate any associated memory usage 
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()
